# %%
from pandas import read_csv, isna

# %%
df = read_csv("euro-daily-hist_1999_2022.csv")

# %%
df.head()
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2023-05-26               1.6439           1.9558            5.3878
# 1   2023-05-25               1.6443           1.9558            5.3320
# 2   2023-05-24               1.6402           1.9558            5.3397
# 3   2023-05-23               1.6282           1.9558            5.3649
# 4   2023-05-22               1.6294           1.9558            5.4056
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.4630         0.9707                   7.5874              NaN
# 1             1.4599         0.9708                   7.5891              NaN
# 2             1.4600         0.9732                   7.6005              NaN
# 3             1.4571         0.9718                   7.6039              NaN
# 4             1.4618         0.9700                   7.6067              NaN
#
# ...

# %%
df.tail()
# Out:
#      Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 6306   1999-01-08               1.8406              NaN               NaN
# 6307   1999-01-07               1.8474              NaN               NaN
# 6308   1999-01-06               1.8820              NaN               NaN
# 6309   1999-01-05               1.8944              NaN               NaN
# 6310   1999-01-04               1.9100              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# 6306             1.7643         1.6138                      NaN
# 6307             1.7602         1.6165                      NaN
# 6308             1.7711         1.6116                      NaN
# 6309             1.7965         1.6123                      NaN
# 6310             1.8004         1.6168                      NaN
#
#      [Cypriot pound ] [Czech koruna ] [Danish krone ]  ... [Romanian leu ]  \
# ...

# %%
df.columns
# Out:
# Index(['Period\Unit:', '[Australian dollar ]', '[Bulgarian lev ]',
#        '[Brazilian real ]', '[Canadian dollar ]', '[Swiss franc ]',
#        '[Chinese yuan renminbi ]', '[Cypriot pound ]', '[Czech koruna ]',
#        '[Danish krone ]', '[Estonian kroon ]', '[UK pound sterling ]',
#        '[Greek drachma ]', '[Hong Kong dollar ]', '[Croatian kuna ]',
#        '[Hungarian forint ]', '[Indonesian rupiah ]', '[Israeli shekel ]',
#        '[Indian rupee ]', '[Iceland krona ]', '[Japanese yen ]',
#        '[Korean won ]', '[Lithuanian litas ]', '[Latvian lats ]',
#        '[Maltese lira ]', '[Mexican peso ]', '[Malaysian ringgit ]',
#        '[Norwegian krone ]', '[New Zealand dollar ]', '[Philippine peso ]',
#        '[Polish zloty ]', '[Romanian leu ]', '[Russian rouble ]',
#        '[Swedish krona ]', '[Singapore dollar ]', '[Slovenian tolar ]',
#        '[Slovak koruna ]', '[Thai baht ]', '[Turkish lira ]', '[US dollar ]',
#        '[South African rand ]'],
# ...

# %%
df.__len__()
# Out:
# 6311

# %%
df.drop_duplicates(inplace= True)

# %%
df.__len__()
# Out:
# 6311

# %%
lst_column = []
for i in df.columns :
    lst_column.append(i.replace("[", "").replace("]", "").strip())
lst_column[0] = "Period\\Unit"
lst_column
# Out:
# ['Period\\Unit',
#  'Australian dollar',
#  'Bulgarian lev',
#  'Brazilian real',
#  'Canadian dollar',
#  'Swiss franc',
#  'Chinese yuan renminbi',
#  'Cypriot pound',
#  'Czech koruna',
#  'Danish krone',
#  'Estonian kroon',
#  'UK pound sterling',
#  'Greek drachma',
#  'Hong Kong dollar',
#  'Croatian kuna',
#  'Hungarian forint',
#  'Indonesian rupiah',
#  'Israeli shekel',
#  'Indian rupee',
#  'Iceland krona',
#  'Japanese yen',
#  'Korean won',
#  'Lithuanian litas',
#  'Latvian lats',
#  'Maltese lira',
#  'Mexican peso',
#  'Malaysian ringgit',
#  'Norwegian krone',
#  'New Zealand dollar',
#  'Philippine peso',
#  'Polish zloty',
#  'Romanian leu',
#  'Russian rouble',
#  'Swedish krona',
#  'Singapore dollar',
#  'Slovenian tolar',
#  'Slovak koruna',
#  'Thai baht',
#  'Turkish lira',
#  'US dollar',
#  'South African rand']

# %%
df.columns = lst_column

# %%
df.head()
# Out:
#   Period\Unit Australian dollar Bulgarian lev Brazilian real Canadian dollar  \
# 0  2023-05-26            1.6439        1.9558         5.3878          1.4630
# 1  2023-05-25            1.6443        1.9558         5.3320          1.4599
# 2  2023-05-24            1.6402        1.9558         5.3397          1.4600
# 3  2023-05-23            1.6282        1.9558         5.3649          1.4571
# 4  2023-05-22            1.6294        1.9558         5.4056          1.4618
#
#   Swiss franc Chinese yuan renminbi Cypriot pound Czech koruna Danish krone  \
# 0      0.9707                7.5874           NaN       23.648       7.4489
# 1      0.9708                7.5891           NaN       23.645       7.4502
# 2      0.9732                7.6005           NaN       23.671       7.4477
# 3      0.9718                7.6039           NaN       23.681       7.4475
# 4      0.9700                7.6067           NaN       23.676       7.4478
#
# ...

# %%
df.to_csv("CLEANED_euro_daily_hist_1999-2023.csv",index= False)

# %%
from matplotlib import pyplot as plt

df= read_csv("CLEANED_euro_daily_hist_1999-2023.csv")

# %%
plt.figure(figsize=(60,55))
plt.xlabel("Currencies")
plt.ylabel("Value to Euro")
plt.title("Values of Other Currencies to Euro")
plt.barh( list(df.loc[0].keys())[1:] , [str(i) for i in df.loc[0]][1:], color="lime" )
plt.show()
