# %%
from pandas import read_csv, isna

# %%
df = read_csv("utf-16-space_missions.csv",encoding="utf-16" )

# %%
df.head()
# Out:
#      Company                                   Location        Date      Time  \
# 0  RVSN USSR  Site 1/5, Baikonur Cosmodrome, Kazakhstan  1957-10-04  19:28:00
# 1  RVSN USSR  Site 1/5, Baikonur Cosmodrome, Kazakhstan  1957-11-03  02:30:00
# 2    US Navy   LC-18A, Cape Canaveral AFS, Florida, USA  1957-12-06  16:44:00
# 3       AMBA   LC-26A, Cape Canaveral AFS, Florida, USA  1958-02-01  03:48:00
# 4    US Navy   LC-18A, Cape Canaveral AFS, Florida, USA  1958-02-05  07:33:00
#
#            Rocket         Mission RocketStatus Price MissionStatus
# 0  Sputnik 8K71PS       Sputnik-1      Retired   NaN       Success
# 1  Sputnik 8K71PS       Sputnik-2      Retired   NaN       Success
# 2        Vanguard    Vanguard TV3      Retired   NaN       Failure
# 3          Juno I      Explorer 1      Retired   NaN       Success
# 4        Vanguard  Vanguard TV3BU      Retired   NaN       Failure

# %%
df.tail()
# Out:
#         Company                                         Location        Date  \
# 4625     SpaceX          SLC-4E, Vandenberg SFB, California, USA  2022-07-22
# 4626       CASC  LC-101, Wenchang Satellite Launch Center, China  2022-07-24
# 4627     SpaceX       LC-39A, Kennedy Space Center, Florida, USA  2022-07-24
# 4628  CAS Space           Jiuquan Satellite Launch Center, China  2022-07-27
# 4629       CASC     LC-3, Xichang Satellite Launch Center, China  2022-07-29
#
#           Time            Rocket              Mission RocketStatus  Price  \
# 4625  17:39:00  Falcon 9 Block 5   Starlink Group 3-2       Active     67
# 4626  06:22:00     Long March 5B              Wentian       Active    NaN
# 4627  13:38:00  Falcon 9 Block 5  Starlink Group 4-25       Active     67
# 4628  04:12:00        Zhongke-1A          Demo Flight       Active    NaN
# 4629  13:28:00     Long March 2D   Yaogan 35 Group 03       Active  29.75
#
#      MissionStatus
# 4625       Success
# ...

# %%
df.__len__()
# Out:
# 4630

# %%
df.drop_duplicates().__len__()
# Out:
# 4629

# %%
companies = df.value_counts("Company")
companies
# Out:
# Company
# RVSN USSR           1777
# CASC                 338
# Arianespace          293
# General Dynamics     251
# VKS RF               216
#                     ...
# Douglas                1
# CAS Space              1
# Khrunichev             1
# Landspace              1
# Firefly                1
# Name: count, Length: 62, dtype: int64

# %%
rocketstatus = df.value_counts("RocketStatus")
rocketstatus
# Out:
# RocketStatus
# Retired    3620
# Active     1010
# Name: count, dtype: int64

# %%
missionstatus = df.value_counts("MissionStatus")
missionstatus
# Out:
# MissionStatus
# Success              4162
# Failure               357
# Partial Failure       107
# Prelaunch Failure       4
# Name: count, dtype: int64

# %%
companies[:20]
# Out:
# Company
# RVSN USSR           1777
# CASC                 338
# Arianespace          293
# General Dynamics     251
# VKS RF               216
# NASA                 203
# SpaceX               182
# US Air Force         161
# ULA                  151
# Boeing               136
# Martin Marietta      114
# Northrop              89
# MHI                   87
# ISRO                  82
# Lockheed              79
# Roscosmos             69
# ILS                   46
# Sea Launch            36
# ISAS                  30
# Rocket Lab            28
# Name: count, dtype: int64

# %%
df.value_counts("Price")
# Out:
# Price
# 450      136
# 67       111
# 200       80
# 64.68     58
# 40        57
#         ...
# 135        2
# 55         1
# 20.14      1
# 15         1
# 28.3       1
# Name: count, Length: 65, dtype: int64

# %%
df.head()
# Out:
#      Company                                   Location        Date      Time  \
# 0  RVSN USSR  Site 1/5, Baikonur Cosmodrome, Kazakhstan  1957-10-04  19:28:00
# 1  RVSN USSR  Site 1/5, Baikonur Cosmodrome, Kazakhstan  1957-11-03  02:30:00
# 2    US Navy   LC-18A, Cape Canaveral AFS, Florida, USA  1957-12-06  16:44:00
# 3       AMBA   LC-26A, Cape Canaveral AFS, Florida, USA  1958-02-01  03:48:00
# 4    US Navy   LC-18A, Cape Canaveral AFS, Florida, USA  1958-02-05  07:33:00
#
#            Rocket         Mission RocketStatus Price MissionStatus
# 0  Sputnik 8K71PS       Sputnik-1      Retired   NaN       Success
# 1  Sputnik 8K71PS       Sputnik-2      Retired   NaN       Success
# 2        Vanguard    Vanguard TV3      Retired   NaN       Failure
# 3          Juno I      Explorer 1      Retired   NaN       Success
# 4        Vanguard  Vanguard TV3BU      Retired   NaN       Failure

# %%
df[isna(df["Company"]) == True ]
# Out:
# Empty DataFrame
# Columns: [Company, Location, Date, Time, Rocket, Mission, RocketStatus, Price, MissionStatus]
# Index: []

# %%
df[isna(df["Location"]) == True ]
# Out:
# Empty DataFrame
# Columns: [Company, Location, Date, Time, Rocket, Mission, RocketStatus, Price, MissionStatus]
# Index: []

# %%
df[isna(df["Date"]) == True ]
# Out:
# Empty DataFrame
# Columns: [Company, Location, Date, Time, Rocket, Mission, RocketStatus, Price, MissionStatus]
# Index: []

# %%
df[isna(df["Time"]) == True ]
# Out:
#           Company                                           Location  \
# 13        US Navy  Douglas F4D Skyray, Naval Air Station Point Mu...
# 15        US Navy  Douglas F4D Skyray, Naval Air Station Point Mu...
# 17        US Navy  Douglas F4D Skyray, Naval Air Station Point Mu...
# 19        US Navy  Douglas F4D Skyray, Naval Air Station Point Mu...
# 20        US Navy  Douglas F4D Skyray, Naval Air Station Point Mu...
# ...           ...                                                ...
# 3988          ISA  Imam Khomeini Spaceport, Semnan Space Center, ...
# 4029  Blue Origin    Blue Origin Launch Site, West Texas, Texas, USA
# 4161          ISA  Imam Khomeini Spaceport, Semnan Space Center, ...
# 4217          ISA  Imam Khomeini Spaceport, Semnan Space Center, ...
# 4389          ISA   Launch Platform, Shahrud Missile Test Site, Iran
#
#             Date Time              Rocket       Mission RocketStatus Price  \
# ...

# %%
for i in range(df.__len__()) :
    if isna(df.loc[i,"Time"]) :
        df.loc[i,"Time"] = "00:00:00"
df[isna(df["Time"]) == True]
# Out:
# Empty DataFrame
# Columns: [Company, Location, Date, Time, Rocket, Mission, RocketStatus, Price, MissionStatus]
# Index: []

# %%
df[isna(df["Rocket"]) == True]
# Out:
# Empty DataFrame
# Columns: [Company, Location, Date, Time, Rocket, Mission, RocketStatus, Price, MissionStatus]
# Index: []

# %%
df[isna(df["Mission"]) == True]
# Out:
# Empty DataFrame
# Columns: [Company, Location, Date, Time, Rocket, Mission, RocketStatus, Price, MissionStatus]
# Index: []

# %%
df[isna(df["RocketStatus"]) == True]
# Out:
# Empty DataFrame
# Columns: [Company, Location, Date, Time, Rocket, Mission, RocketStatus, Price, MissionStatus]
# Index: []

# %%
df[isna(df["MissionStatus"]) == True]
# Out:
# Empty DataFrame
# Columns: [Company, Location, Date, Time, Rocket, Mission, RocketStatus, Price, MissionStatus]
# Index: []

# %%
df[isna(df["Price"]) == True]
# Out:
#          Company                                           Location  \
# 0      RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 1      RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 2        US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 3           AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4        US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# ...          ...                                                ...
# 4605        KARI               LC-2, Naro Space Center, South Korea
# 4610  Rocket Lab     Rocket Lab LC-1B, Māhia Peninsula, New Zealand
# 4621         ESA  ELV-1, Guiana Space Centre, French Guiana, France
# 4626        CASC    LC-101, Wenchang Satellite Launch Center, China
# 4628   CAS Space             Jiuquan Satellite Launch Center, China
#
#             Date      Time           Rocket             Mission RocketStatus  \
# ...

# %%
for i in range(df.__len__()) :
    if isna(df.loc[i,"Price"]) :
        df.loc[i,"Price"] = 0;
df[isna(df["Price"]) == True]
# Out:
# Empty DataFrame
# Columns: [Company, Location, Date, Time, Rocket, Mission, RocketStatus, Price, MissionStatus]
# Index: []

# %%
df.head()
# Out:
#      Company                                   Location        Date      Time  \
# 0  RVSN USSR  Site 1/5, Baikonur Cosmodrome, Kazakhstan  1957-10-04  19:28:00
# 1  RVSN USSR  Site 1/5, Baikonur Cosmodrome, Kazakhstan  1957-11-03  02:30:00
# 2    US Navy   LC-18A, Cape Canaveral AFS, Florida, USA  1957-12-06  16:44:00
# 3       AMBA   LC-26A, Cape Canaveral AFS, Florida, USA  1958-02-01  03:48:00
# 4    US Navy   LC-18A, Cape Canaveral AFS, Florida, USA  1958-02-05  07:33:00
#
#            Rocket         Mission RocketStatus Price MissionStatus
# 0  Sputnik 8K71PS       Sputnik-1      Retired     0       Success
# 1  Sputnik 8K71PS       Sputnik-2      Retired     0       Success
# 2        Vanguard    Vanguard TV3      Retired     0       Failure
# 3          Juno I      Explorer 1      Retired     0       Success
# 4        Vanguard  Vanguard TV3BU      Retired     0       Failure

# %%
df.tail()
# Out:
#         Company                                         Location        Date  \
# 4625     SpaceX          SLC-4E, Vandenberg SFB, California, USA  2022-07-22
# 4626       CASC  LC-101, Wenchang Satellite Launch Center, China  2022-07-24
# 4627     SpaceX       LC-39A, Kennedy Space Center, Florida, USA  2022-07-24
# 4628  CAS Space           Jiuquan Satellite Launch Center, China  2022-07-27
# 4629       CASC     LC-3, Xichang Satellite Launch Center, China  2022-07-29
#
#           Time            Rocket              Mission RocketStatus  Price  \
# 4625  17:39:00  Falcon 9 Block 5   Starlink Group 3-2       Active     67
# 4626  06:22:00     Long March 5B              Wentian       Active      0
# 4627  13:38:00  Falcon 9 Block 5  Starlink Group 4-25       Active     67
# 4628  04:12:00        Zhongke-1A          Demo Flight       Active      0
# 4629  13:28:00     Long March 2D   Yaogan 35 Group 03       Active  29.75
#
#      MissionStatus
# 4625       Success
# ...

# %%
df[df["Price"] != 0]
# Out:
#            Company                                      Location        Date  \
# 303   US Air Force      SLC-20, Cape Canaveral AFS, Florida, USA  1964-09-01
# 323   US Air Force      SLC-20, Cape Canaveral AFS, Florida, USA  1964-12-10
# 330   US Air Force      SLC-20, Cape Canaveral AFS, Florida, USA  1965-02-11
# 352   US Air Force      SLC-20, Cape Canaveral AFS, Florida, USA  1965-05-06
# 468   US Air Force       SLC-4W, Vandenberg AFB, California, USA  1966-07-29
# ...            ...                                           ...         ...
# 4623          CASC  LC-9, Taiyuan Satellite Launch Center, China  2022-07-15
# 4624        SpaceX      SLC-40, Cape Canaveral SFS, Florida, USA  2022-07-17
# 4625        SpaceX       SLC-4E, Vandenberg SFB, California, USA  2022-07-22
# 4627        SpaceX    LC-39A, Kennedy Space Center, Florida, USA  2022-07-24
# 4629          CASC  LC-3, Xichang Satellite Launch Center, China  2022-07-29
#
# ...

# %%
df["Location"].value_counts()
# Out:
# Location
# Site 31/6, Baikonur Cosmodrome, Kazakhstan               251
# Site 132/1, Plesetsk Cosmodrome, Russia                  216
# Site 43/4, Plesetsk Cosmodrome, Russia                   211
# Site 41/1, Plesetsk Cosmodrome, Russia                   198
# Site 1/5, Baikonur Cosmodrome, Kazakhstan                193
#                                                         ...
# Pad A, Boca Chica, Texas, USA                              1
# K-496 Submarine, Barents Sea Launch Area, Barents Sea      1
# Launch Plateform, Shahrud Missile Test Site                1
# K-84 Submarine, Barents Sea Launch Area, Barents Sea       1
# LC-9A, Taiyuan Satellite Launch Center, China              1
# Name: count, Length: 158, dtype: int64

# %%
df[df["Location"] == "Site 31/6, Baikonur Cosmodrome, Kazakhstan" ]
# Out:
#         Company                                    Location        Date  \
# 276   RVSN USSR  Site 31/6, Baikonur Cosmodrome, Kazakhstan  1964-04-04
# 281   RVSN USSR  Site 31/6, Baikonur Cosmodrome, Kazakhstan  1964-04-25
# 287   RVSN USSR  Site 31/6, Baikonur Cosmodrome, Kazakhstan  1964-06-10
# 288   RVSN USSR  Site 31/6, Baikonur Cosmodrome, Kazakhstan  1964-06-23
# 293   RVSN USSR  Site 31/6, Baikonur Cosmodrome, Kazakhstan  1964-07-15
# ...         ...                                         ...         ...
# 4517  Roscosmos  Site 31/6, Baikonur Cosmodrome, Kazakhstan  2021-12-08
# 4532    Starsem  Site 31/6, Baikonur Cosmodrome, Kazakhstan  2021-12-27
# 4551  Roscosmos  Site 31/6, Baikonur Cosmodrome, Kazakhstan  2022-02-15
# 4565  Roscosmos  Site 31/6, Baikonur Cosmodrome, Kazakhstan  2022-03-18
# 4598  Roscosmos  Site 31/6, Baikonur Cosmodrome, Kazakhstan  2022-06-03
#
#           Time             Rocket                         Mission  \
# ...
